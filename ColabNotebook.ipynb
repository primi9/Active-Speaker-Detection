# %%
# !git clone https://github.com/primi9/Active-Speaker-Detection.git

# %%
# !pip3 install yt-dlp
# !yt-dlp -f "bestvideo[ext=mp4]+bestaudio[ext=m4a]/best" https://www.youtube.com/watch?v=EpJ8yKGl0Q4 -o test.mp4

# %%
! python asd/runThis.py test.mp4 --install
